# %%
import diff_classifier.aws as aws
import skimage.io as sio
import diff_register.register as rg
# %matplotlib inline

# %%
rdir = 'registration'
prefix = 'CC9_S4'
rfname = '{}/{}.tif'.format(rdir, prefix)
fname = '{}.tif'.format(prefix)
sfname = '{}_s.tif'.format(prefix)

# %%
aws.download_s3(rfname, fname)

# %%
massive = sio.imread(fname)

# %%
from skimage import transform as tf

# %%
test1 = rg.downsample(fname)
test2 = rg.downsample(fname)
# Out:
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: CC9_S4_s.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
im1, im2 = rg.plot_together(test1[0, :, :], test2[0, :, :])
