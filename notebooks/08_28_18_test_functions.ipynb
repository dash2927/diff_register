# %%
import skimage.io as sio
import numpy as np
import diff_register.im_process as imp
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
np.random.seed(seed=1)
testim = np.random.exponential(1, size=(40, 40))
testim = testim / np.max(testim)
sio.imsave('test.tif', testim)

# %%
sio.imshow(testim)
# Out:
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
tname = 'cheeky.tif'

testbi = imp.binary_image('.', 'test.tif', threshold=0.01, figsize=(5,5), show=True, ajar=True, close=True, imname=None)

# %%
os.path.isfile('clean_test.tif')
# Out:
# True

# %%
sio.imsave('./{}'.format(tname), testbi)

# %%
os.path.isfile(tname)
